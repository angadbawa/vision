# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
cd 'drive/MyDrive/Pneumonia_Normal_Class'
# Out:
# /content/drive/MyDrive/Pneumonia_Normal_Class

# %%
# !unzip input.zip

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import os
import glob
import h5py
import shutil
import imgaug as aug
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.image as mimg
import imgaug.augmenters as iaa
from os import listdir, makedirs, getcwd, remove
from os.path import isfile, join, abspath, exists, isdir, expanduser
from PIL import Image
from pathlib import Path
from skimage.io import imread
from skimage.transform import resize
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input
from tensorflow.keras.utils import load_img,  img_to_array
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, Input, Flatten, SeparableConv2D
from tensorflow.keras.layers import GlobalMaxPooling2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers.legacy import Adam
# from tensorflow.keras.optimizers import Adam, SGD, RMSprop
from tensorflow.keras.callbacks import ModelCheckpoint, Callback, EarlyStopping
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix
import cv2
from keras import backend as K
color = sns.color_palette()
# %matplotlib inline

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory
print(os.listdir("./input"))
# Out:
# ['chest-xray-pneumonia']

# %%
import tensorflow as tf

# Set the seed for hash based operations in python
os.environ['PYTHONHASHSEED'] = '0'

# Set the numpy seed
np.random.seed(111)

# Disable multi-threading in tensorflow ops
session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)

# Set the random seed in tensorflow at graph level
tf.random.set_seed(111)

# Define a tensorflow session with above session configs
sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
tf.compat.v1.keras.backend.set_session(sess)

# Make the augmentation sequence deterministic
aug.seed(111)

# %%
# Define path to the data directory
data_dir = Path('../input/chest-xray-pneumonia/chest_xray')

# Path to train directory (Fancy pathlib...no more os.path!!)
train_dir = data_dir / 'train'

# Path to validation directory
val_dir = data_dir / 'val'

# Path to test directory
test_dir = data_dir / 'test'

# %%
# Get the path to the normal and pneumonia sub-directories
normal_cases_dir = train_dir / 'NORMAL'
pneumonia_cases_dir = train_dir / 'PNEUMONIA'

# %%
normal_cases_dir
# Out:
# PosixPath('../input/chest-xray-pneumonia/chest_xray/train/NORMAL')

# %%
# Get the list of all the images
# normal_cases = normal_cases_dir.glob('./*.jpeg')
# pneumonia_cases = pneumonia_cases_dir.glob('./*.jpeg')

normal_cases=glob.glob("./input/chest-xray-pneumonia/chest_xray/train/NORMAL/*")
pneumonia_cases=glob.glob("./input/chest-xray-pneumonia/chest_xray/train/PNEUMONIA/*")

# %%
# list(normal_cases)

# %%
# An empty list. We will insert the data into this list in (img_path, label) format
train_data = []

# Go through all the normal cases. The label for these cases will be 0
for img in normal_cases:
    print(img)
    train_data.append((img,0))

# Go through all the pneumonia cases. The label for these cases will be 1
for img in pneumonia_cases:
    train_data.append((img, 1))

# Get a pandas dataframe from the data we have in our list 
train_data = pd.DataFrame(train_data, columns=['image', 'label'],index=None)

# Shuffle the data 
train_data = train_data.sample(frac=1.).reset_index(drop=True)

# How the dataframe looks like?
train_data.head()
# Out:
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3486729-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3360834-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3207024-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3260755-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3371493-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3411116-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-339692-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3411116-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3342765-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3040444-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3170978-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3229887-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3487615-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3175613-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3444356-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3156332-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3387483-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3448549-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3573766-0003.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-388586-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3907168-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3685250-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3803096-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3860648-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3860648-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3514363-0004.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-385855-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3780378-0003.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3580922-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3678361-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-385855-0004.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3644944-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-385855-0003.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3881206-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3502771-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3573766-0004.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3802540-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3789615-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3747940-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3852346-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3823741-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3802540-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3706164-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3514363-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-388586-0003.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3780378-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3573766-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3873301-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-385855-0005.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3902817-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3789615-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3532468-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3861947-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-385855-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3573766-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3518933-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3852346-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3848106-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3514363-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3758513-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3744309-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3758513-0004.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3624836-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3853265-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3751100-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3781678-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3848106-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3570271-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3688916-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3758513-0003.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3744578-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3644944-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3665449-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-388586-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3853078-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3758513-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3514363-0003.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3526928-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3684474-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3861947-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3526928-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3873301-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3853078-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-390699-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3781678-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3644944-0003.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3802697-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3780378-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3821719-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3688916-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3895972-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3518933-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3852346-0003.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3518986-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4223385-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4051219-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4241606-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4241606-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3908973-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4358449-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4164846-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3949386-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4241389-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4122298-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4286410-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4267417-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4019172-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4418958-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4418958-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4119877-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4241389-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3949386-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3982198-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4212770-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4320287-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3964800-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4190635-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4199443-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3964800-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4240389-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4296383-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4164846-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-431263-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4027257-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3997421-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3958628-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4317334-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4159337-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4090456-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4271375-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4447575-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4377146-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4316614-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4418958-0004.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4056615-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4486854-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3969882-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4019172-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4184691-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4092650-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3948906-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-445267-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4019172-0003.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3952204-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4099158-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-447225-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4178405-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3969882-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4092650-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3948906-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4205289-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4178405-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4008560-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4464072-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4314990-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4178256-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4221981-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4418958-0003.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4056615-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4179172-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4047118-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4221981-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3975363-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4199443-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4173304-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4320287-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4358449-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4234436-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4316614-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4093513-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4421061-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4175731-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5042453-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4678619-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4587209-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4824082-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5008447-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4499436-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4900810-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4689461-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4669070-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4678619-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4973676-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5042453-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4507677-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4663193-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5001531-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5050179-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4605989-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4688588-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4769977-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4669070-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4617560-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4982187-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4734216-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4656588-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-471048-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4853105-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4496165-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4515478-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4680404-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4951226-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4969331-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4680404-0003.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4638373-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4507677-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4791400-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-462175-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4521403-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4680404-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4859175-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4557620-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4758820-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-452722-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4587209-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4635177-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4587209-0003.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4839411-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-471293-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4649665-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5049026-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4612356-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4946392-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4735535-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4994733-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4786732-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5031579-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4867871-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4843653-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5015362-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-483610-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4515541-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4694540-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4680404-0004.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4769977-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-462175-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4515478-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4500184-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5031579-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5021371-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4748580-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4528586-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-473372-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4758820-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4798472-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4942258-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4829481-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4943890-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4751528-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4758820-0003.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-4791400-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5222567-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5633781-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5633781-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5431669-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5170916-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5379127-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5126891-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5571242-0003.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5227108-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5264964-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5161959-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5087693-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-518175-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-534646-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5606086-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5355820-0003.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5545083-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5061991-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-559372-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5387596-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5504914-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5426353-0003.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5505017-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5401202-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5602301-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5075834-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5332597-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-546828-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5288174-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5277056-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5187821-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5505017-0004.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5623914-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5401202-0004.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5543895-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5488799-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5355820-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5618998-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5389167-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5176049-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5427599-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5638457-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5234465-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5397211-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5422966-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5409923-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5634312-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5357348-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5397211-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5634312-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5488799-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5243995-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5575488-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5505017-0003.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5090771-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5571242-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5355820-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5315468-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5080539-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-557197-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5227306-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5528656-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5398062-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5514751-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-506998-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5571242-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5452786-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5545083-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5386916-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-508988-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5082504-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5270355-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5401202-0003.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5075834-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5426353-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5236765-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5240418-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5426353-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5401202-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5505017-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5430880-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5802954-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5740995-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5877265-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5943572-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5935431-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5724628-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6112892-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5693915-0004.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6054279-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5726309-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5850175-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5693915-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5693915-0003.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6044102-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5762763-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5833288-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6126748-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5759621-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5918516-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6137902-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5791834-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5845895-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6090737-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-591136-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-597494-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6081265-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5729564-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5799769-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5650764-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5840376-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5816980-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5661210-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5676630-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5722320-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5849113-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5887026-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6047821-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6002769-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5970247-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6123465-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6095394-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5940371-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5911363-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6062926-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6143989-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5729327-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5651147-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6090737-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5918516-0003.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6044251-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5881224-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5759621-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6116579-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6073662-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5659176-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5745959-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5708209-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6015567-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5740995-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5748384-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5650764-0003.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5708108-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6084744-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5918516-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5752258-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5911363-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5729564-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6015860-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5693915-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6112892-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5887943-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-566227-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-566227-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5728847-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5728847-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5816980-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5650764-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6062926-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6073662-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-5673735-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6271808-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6351934-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6193719-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6830488-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6710847-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6495836-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6593605-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6319993-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6430619-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6205754-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6642991-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6214135-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6688691-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6671728-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6648483-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6474092-0003.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6505040-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-678492-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6369415-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6432470-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6474092-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6644752-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6219029-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6417148-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6474092-0004.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6712268-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6644752-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6474092-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6440809-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6328273-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6466991-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6644501-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6524946-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6806808-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6533909-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6802620-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6226952-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6351934-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6511522-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6710847-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6593605-0003.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-678492-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6217600-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6315622-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6309200-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6156730-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6369415-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6847348-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6153007-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6315622-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6619597-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6593605-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6702380-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6505040-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6367802-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6237780-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6731317-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-652570-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6396089-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6534324-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6727820-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6462536-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6237780-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6433176-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6433176-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6722546-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6346076-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6227100-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6194746-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6336339-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6459868-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-618803-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6575898-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6661503-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-66795-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6248376-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-673276-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6478227-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6299880-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6357850-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6836464-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6251505-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6873457-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6901859-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-7019096-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6954688-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-7055226-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-7049415-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6977054-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-7103127-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6943766-0003.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6893621-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-7075596-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-7133593-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-7061098-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-7133593-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-7105903-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6897353-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-695402-0003.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6931624-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6960239-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6973172-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6984314-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6915237-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-705474-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-7033377-0003.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-7123604-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6972373-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-701579-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-695402-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6891737-0003.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-7049415-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-7001302-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-7146748-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-7033377-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-705474-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-7140141-0004.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6943766-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-695402-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6943766-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-7049415-0003.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-7103127-0003.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6974833-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6972088-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6954688-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-7103127-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-7140141-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6847348-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6973172-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6978858-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-7105903-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6960239-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-7019096-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6943766-0004.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6964800-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-71482-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-7090700-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6971619-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6881695-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-7061169-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6891737-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-705219-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-7138775-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-701579-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6891737-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-7140141-0003.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-7054672-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6892511-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6901859-0003.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6882169-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-7140141-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6960867-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6901859-0004.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-712032-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-7033377-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-703667-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-7019096-0003.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-6901859-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-7091193-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-705219-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-7335645-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-7252162-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-7212555-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-7483422-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-7542794-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-7223437-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-7323530-0004.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-7478601-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-7233940-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-7301799-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-7298141-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-7605239-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-7298141-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-7436212-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-7575893-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-7534217-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-7218663-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-7330624-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-7635797-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-7389271-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-7461661-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-7478601-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-7230473-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-7570480-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-7436212-0003.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-7155475-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-7448311-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-7451061-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-7463705-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-7397628-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-7461661-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-7323530-0003.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-7333515-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-7252162-0003.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-7252162-0004.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-7436212-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-7368970-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-74708-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-7323530-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-7333515-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-7230473-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-7649100-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-7298793-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-7236520-0001.jpeg
# ...
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2386123-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2214391-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2154341-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2253299-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-229022-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2272901-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2257508-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2257508-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2344710-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2076945-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2415019-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2239178-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2140240-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2460811-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2068214-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2154341-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2031622-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2204525-0003.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2180796-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2416577-0003.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-230877-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2481508-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2333546-0004.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2239107-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-221753-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2416577-0004.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2432050-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2239107-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2280482-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2395964-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2335549-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2285600-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2230350-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2333546-0003.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2239107-0003.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2187139-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2315098-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-202916-0003.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2451318-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2415177-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2239132-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2150838-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2338211-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2255274-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2416577-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2395964-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2460811-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-233341-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2282444-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2337422-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2469830-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2233981-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2474988-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2344710-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2214391-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2285600-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2416577-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2244273-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2048417-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2140240-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2339168-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2411226-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2211620-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2362538-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2949692-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2881863-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2552119-0003.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2675017-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2705424-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-28501-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2559035-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2550782-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2537399-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2537399-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2768393-0003.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2521614-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2728496-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2768393-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2552119-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2768393-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2723532-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2695944-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2504415-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2597757-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2926567-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2558319-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2986373-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2736751-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-293382-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-263932-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2523281-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2491954-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2984327-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-284113-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2655558-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2768393-0005.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2597757-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2646645-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2705424-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2890238-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2823265-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2675017-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2565226-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2768393-0006.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2697110-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2768393-0004.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2552119-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-284113-0003.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-275284-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2957919-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2646923-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2697110-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2558319-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2699389-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2528215-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2914942-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2487179-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2689107-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2550592-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2541618-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2860555-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2885344-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2881687-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2559035-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2983256-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2699389-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-284113-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2723350-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2659844-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2808220-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2705424-0003.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2568157-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2801235-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2779359-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2517971-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2550592-0003.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2692080-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-252489-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2550592-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2504415-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3220570-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3400382-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3119430-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3147147-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3400382-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3482198-0003.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3333785-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3006949-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3175147-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3108988-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3402813-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3269314-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3399582-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3502771-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3271929-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3342765-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3482198-0004.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3037101-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-338872-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3168931-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3072074-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2992797-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3194625-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3243013-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3054452-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3484856-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3175147-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-324309-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3271929-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3103404-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3073180-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-339692-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3079343-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3411116-0003.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3220570-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3250852-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3190806-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3178986-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2996766-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3178986-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3220570-0004.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-32326-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3220570-0003.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3482198-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3375999-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3333785-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3156332-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3103404-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3373762-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3476904-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3387483-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3006949-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3144575-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3229529-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3229887-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-332359-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-2992797-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3399582-0001.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3482198-0002.jpeg
# ./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-3493370-0001.jpeg
#                                                image  label
# 0  ./input/chest-xray-pneumonia/chest_xray/train/...      1
# 1  ./input/chest-xray-pneumonia/chest_xray/train/...      0
# 2  ./input/chest-xray-pneumonia/chest_xray/train/...      1
# 3  ./input/chest-xray-pneumonia/chest_xray/train/...      1
# 4  ./input/chest-xray-pneumonia/chest_xray/train/...      1

# %%
# Get the counts for each class
cases_count = train_data['label'].value_counts()
print(cases_count)

# Plot the results 
plt.figure(figsize=(10,8))
sns.barplot(x=cases_count.index, y= cases_count.values)
plt.title('Number of cases', fontsize=14)
plt.xlabel('Case type', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.xticks(range(len(cases_count.index)), ['Normal(0)', 'Pneumonia(1)'])
plt.show()
# Out:
# 1    3855
# 0    1349
# Name: label, dtype: int64

# %%
# Get few samples for both the classes
pneumonia_samples = (train_data[train_data['label']==1]['image'].iloc[:5]).tolist()
normal_samples = (train_data[train_data['label']==0]['image'].iloc[:5]).tolist()

# Concat the data in a single list and del the above two list
samples = pneumonia_samples + normal_samples
del pneumonia_samples, normal_samples

# Plot the data 
f, ax = plt.subplots(2,5, figsize=(30,10))
for i in range(10):
    img = imread(samples[i])
    ax[i//5, i%5].imshow(img, cmap='gray')
    if i<5:
        ax[i//5, i%5].set_title("Pneumonia")
    else:
        ax[i//5, i%5].set_title("Normal")
    ax[i//5, i%5].axis('off')
    ax[i//5, i%5].set_aspect('auto')
plt.show()

# %%
# Get the path to the sub-directories
# normal_cases_dir = val_dir / 'NORMAL'
# pneumonia_cases_dir = val_dir / 'PNEUMONIA'

normal_cases=glob.glob("./input/chest-xray-pneumonia/chest_xray/val/NORMAL/*")
pneumonia_cases=glob.glob("./input/chest-xray-pneumonia/chest_xray/val/PNEUMONIA/*")

# Get the list of all the images
# normal_cases = normal_cases_dir.glob('*')
# pneumonia_cases = pneumonia_cases_dir.glob('*')

# List that are going to contain validation images data and the corresponding labels
valid_data = []
valid_labels = []


# Some images are in grayscale while majority of them contains 3 channels. So, if the image is grayscale, we will convert into a image with 3 channels.
# We will normalize the pixel values and resizing all the images to 224x224 

# Normal cases
for img in normal_cases:
    img = cv2.imread(str(img))
    img = cv2.resize(img, (224,224))
    if img.shape[2] ==1:
        img = np.dstack([img, img, img])
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = img.astype(np.float32)/255.
    label = to_categorical(0, num_classes=2)
    valid_data.append(img)
    valid_labels.append(label)
                      
# Pneumonia cases        
for img in pneumonia_cases:
    img = cv2.imread(str(img))
    img = cv2.resize(img, (224,224))
    if img.shape[2] ==1:
        img = np.dstack([img, img, img])
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = img.astype(np.float32)/255.
    label = to_categorical(1, num_classes=2)
    valid_data.append(img)
    valid_labels.append(label)
    
# Convert the list into numpy arrays
valid_data = np.array(valid_data)
valid_labels = np.array(valid_labels)

print("Total number of validation examples: ", valid_data.shape)
print("Total number of labels:", valid_labels.shape)
# Out:
# Total number of validation examples:  (206, 224, 224, 3)
# Total number of labels: (206, 2)

# %%
# Augmentation sequence 
seq = iaa.OneOf([
    iaa.Fliplr(), # horizontal flips
    iaa.Affine(rotate=20), # roatation
    iaa.Multiply((1.2, 1.5))]) #random brightness

# %%
def data_gen(data, batch_size):
    # Get total number of samples in the data
    n = len(data)
    steps = n//batch_size
    
    # Define two numpy arrays for containing batch data and labels
    batch_data = np.zeros((batch_size, 224, 224, 3), dtype=np.float32)
    batch_labels = np.zeros((batch_size,2), dtype=np.float32)

    # Get a numpy array of all the indices of the input data
    indices = np.arange(n)
    
    # Initialize a counter
    i =0
    while True:
        np.random.shuffle(indices)
        # Get the next batch 
        count = 0
        next_batch = indices[(i*batch_size):(i+1)*batch_size]
        for j, idx in enumerate(next_batch):
            img_name = data.iloc[idx]['image']
            label = data.iloc[idx]['label']
            
            # one hot encoding
            encoded_label = to_categorical(label, num_classes=2)
            # read the image and resize
            img = cv2.imread(str(img_name))
            img = cv2.resize(img, (224,224))
            
            # check if it's grayscale
            if img.shape[2]==1:
                img = np.dstack([img, img, img])
            
            # cv2 reads in BGR mode by default
            orig_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            # normalize the image pixels
            orig_img = img.astype(np.float32)/255.
            
            batch_data[count] = orig_img
            batch_labels[count] = encoded_label
            
            # generating more samples of the undersampled class
            if label==0 and count < batch_size-2:
                aug_img1 = seq.augment_image(img)
                aug_img2 = seq.augment_image(img)
                aug_img1 = cv2.cvtColor(aug_img1, cv2.COLOR_BGR2RGB)
                aug_img2 = cv2.cvtColor(aug_img2, cv2.COLOR_BGR2RGB)
                aug_img1 = aug_img1.astype(np.float32)/255.
                aug_img2 = aug_img2.astype(np.float32)/255.

                batch_data[count+1] = aug_img1
                batch_labels[count+1] = encoded_label
                batch_data[count+2] = aug_img2
                batch_labels[count+2] = encoded_label
                count +=2
            
            else:
                count+=1
            
            if count==batch_size-1:
                break
            
        i+=1
        yield batch_data, batch_labels
            
        if i>=steps:
            i=0

# %%
def build_model():
    input_img = Input(shape=(224,224,3), name='ImageInput')
    x = Conv2D(64, (3,3), activation='relu', padding='same', name='Conv1_1')(input_img)
    x = Conv2D(64, (3,3), activation='relu', padding='same', name='Conv1_2')(x)
    x = MaxPooling2D((2,2), name='pool1')(x)
    
    x = SeparableConv2D(128, (3,3), activation='relu', padding='same', name='Conv2_1')(x)
    x = SeparableConv2D(128, (3,3), activation='relu', padding='same', name='Conv2_2')(x)
    x = MaxPooling2D((2,2), name='pool2')(x)
    
    x = SeparableConv2D(256, (3,3), activation='relu', padding='same', name='Conv3_1')(x)
    x = BatchNormalization(name='bn1')(x)
    x = SeparableConv2D(256, (3,3), activation='relu', padding='same', name='Conv3_2')(x)
    x = BatchNormalization(name='bn2')(x)
    x = SeparableConv2D(256, (3,3), activation='relu', padding='same', name='Conv3_3')(x)
    x = MaxPooling2D((2,2), name='pool3')(x)
    
    x = SeparableConv2D(512, (3,3), activation='relu', padding='same', name='Conv4_1')(x)
    x = BatchNormalization(name='bn3')(x)
    x = SeparableConv2D(512, (3,3), activation='relu', padding='same', name='Conv4_2')(x)
    x = BatchNormalization(name='bn4')(x)
    x = SeparableConv2D(512, (3,3), activation='relu', padding='same', name='Conv4_3')(x)
    x = MaxPooling2D((2,2), name='pool4')(x)
    
    x = Flatten(name='flatten')(x)
    x = Dense(1024, activation='relu', name='fc1')(x)
    x = Dropout(0.7, name='dropout1')(x)
    x = Dense(512, activation='relu', name='fc2')(x)
    x = Dropout(0.5, name='dropout2')(x)
    x = Dense(2, activation='softmax', name='fc3')(x)
    
    model = Model(inputs=input_img, outputs=x)
    return model

# %%
model =  build_model()
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  ImageInput (InputLayer)     [(None, 224, 224, 3)]     0
#
#  Conv1_1 (Conv2D)            (None, 224, 224, 64)      1792
#
#  Conv1_2 (Conv2D)            (None, 224, 224, 64)      36928
#
#  pool1 (MaxPooling2D)        (None, 112, 112, 64)      0
#
#  Conv2_1 (SeparableConv2D)   (None, 112, 112, 128)     8896
#
#  Conv2_2 (SeparableConv2D)   (None, 112, 112, 128)     17664
#
#  pool2 (MaxPooling2D)        (None, 56, 56, 128)       0
#
#  Conv3_1 (SeparableConv2D)   (None, 56, 56, 256)       34176
#
#  bn1 (BatchNormalization)    (None, 56, 56, 256)       1024
#
#  Conv3_2 (SeparableConv2D)   (None, 56, 56, 256)       68096
#
#  bn2 (BatchNormalization)    (None, 56, 56, 256)       1024
#
#  Conv3_3 (SeparableConv2D)   (None, 56, 56, 256)       68096
#
#  pool3 (MaxPooling2D)        (None, 28, 28, 256)       0
#
#  Conv4_1 (SeparableConv2D)   (None, 28, 28, 512)       133888
#
#  bn3 (BatchNormalization)    (None, 28, 28, 512)       2048
#
#  Conv4_2 (SeparableConv2D)   (None, 28, 28, 512)       267264
#
#  bn4 (BatchNormalization)    (None, 28, 28, 512)       2048
#
#  Conv4_3 (SeparableConv2D)   (None, 28, 28, 512)       267264
#
#  pool4 (MaxPooling2D)        (None, 14, 14, 512)       0
#
#  flatten (Flatten)           (None, 100352)            0
#
#  fc1 (Dense)                 (None, 1024)              102761472
#
#  dropout1 (Dropout)          (None, 1024)              0
#
#  fc2 (Dense)                 (None, 512)               524800
#
#  dropout2 (Dropout)          (None, 512)               0
#
#  fc3 (Dense)                 (None, 2)                 1026
#
# =================================================================
# Total params: 104,197,506
# Trainable params: 104,194,434
# Non-trainable params: 3,072
# _________________________________________________________________

# %%
from keras.utils import plot_model
plot_model(model, show_shapes=True, show_layer_names=True, to_file='model.png')
from IPython.display import Image
Image(retina=True, filename='model.png')

# %%
opt = Adam(lr=0.0001, decay=1e-5)
es = EarlyStopping(patience=5)
chkpt = ModelCheckpoint(filepath='best_model_todate', save_best_only=True, save_weights_only=True)
model.compile(loss='binary_crossentropy', metrics=['accuracy'],optimizer=opt)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/optimizers/legacy/adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
batch_size = 16
nb_epochs = 50

# Get a train data generator
train_data_gen = data_gen(data=train_data, batch_size=batch_size)

# Define the number of training steps
nb_train_steps = train_data.shape[0]//batch_size

print("Number of training and validation steps: {} and {}".format(nb_train_steps, len(valid_data)))
# Out:
# Number of training and validation steps: 325 and 206

# %%
# Fit the model
history = model.fit_generator(train_data_gen, epochs=nb_epochs, steps_per_epoch=nb_train_steps,
                              validation_data=(valid_data, valid_labels),callbacks=[es, chkpt],
                              class_weight={0:1.0, 1:0.4})
# Out:
# <ipython-input-25-f48b82a8e34c>:2: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(train_data_gen, epochs=nb_epochs, steps_per_epoch=nb_train_steps,
# Epoch 1/50
#  17/325 [>.............................] - ETA: 23:28 - loss: 0.4537 - accuracy: 0.4485
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-f48b82a8e34c> in <cell line: 2>()
#       1 # Fit the model
# ----> 2 history = model.fit_generator(train_data_gen, epochs=nb_epochs, steps_per_epoch=nb_train_steps,
#       3                               validation_data=(valid_data, valid_labels),callbacks=[es, chkpt],
#       4                               class_weight={0:1.0, 1:0.4})
#
# /usr/local/lib/python3.10/dist-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2634             stacklevel=2,
#    2635         )
# -> 2636         return self.fit(
#    2637             generator,
#    2638             steps_per_epoch=steps_per_epoch,
#
# /usr/local/lib/python3.10/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1683                         ):
#    1684                             callbacks.on_train_batch_begin(step)
# -> 1685                             tmp_logs = self.train_function(iterator)
#    1686                             if data_handler.should_sync:
#    1687                                 context.async_wait()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     892
#     893       with OptionalXlaContext(self._jit_compile):
# --> 894         result = self._call(*args, **kwds)
#     895
#     896       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     924       # In this case we have created variables on the first call, so we run the
#     925       # defunned version which is guaranteed to never create variables.
# --> 926       return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     927     elif self._variable_creation_fn is not None:
#     928       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py in __call__(self, *args, **kwargs)
#     141       (concrete_function,
#     142        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 143     return concrete_function._call_flat(
#     144         filtered_flat_args, captured_inputs=concrete_function.captured_inputs)  # pylint: disable=protected-access
#     145
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1755         and executing_eagerly):
#    1756       # No tape is watching; skip to running the function.
# -> 1757       return self._build_call_outputs(self._inference_function.call(
#    1758           ctx, args, cancellation_manager=cancellation_manager))
#    1759     forward_backward = self._select_forward_and_backward_functions(
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py in call(self, ctx, args, cancellation_manager)
#     379       with _InterpolateFunctionError(self):
#     380         if cancellation_manager is None:
# --> 381           outputs = execute.execute(
#     382               str(self.signature.name),
#     383               num_outputs=self._num_outputs,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50   try:
#      51     ctx.ensure_initialized()
# ---> 52     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                         inputs, attrs, num_outputs)
#      54   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
# model.save('Pneumonia_Normal_Classification.h5')

# %%
from tensorflow import keras
model = keras.models.load_model('Pneumonia_Normal_Classification.h5')

# %%
from tensorflow.keras.preprocessing import image
img = image.load_img('./input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL-996167-0001.jpeg', target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
# C:\Users\Nikhil Sharma\Downloads\input\chest-xray-pneumonia\chest_xray\val\PNEUMONIA

# %%
images = np.vstack([x])
classes = model.predict(images, batch_size=10)
y_classes = classes.argmax(axis=-1)
print(y_classes)
if y_classes[0] == 0:
  class_txt = 'normal'
  color = 'blue'
else:
  color = 'red'
  class_txt = 'pneumonia'
# Out:
# 1/1 [==============================] - 1s 579ms/step
# [0]

# %%
plt.text(15, 15, class_txt, fontsize=22, color=color)
plt.imshow(img)
